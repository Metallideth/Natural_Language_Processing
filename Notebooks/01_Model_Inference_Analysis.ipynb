# %%
import pickle
import pandas as pd
from tqdm import tqdm

# %%
# Load in validation results
with open('../logging/13-02-2024_2126/epoch07_train_val_summary','rb') as file:
    val_results = pickle.load(file)

# %%
# Take a look at accuracy of the validation results - these will be used to establish the weights for the loss function
# As in the model training, the weights for loss are based on 1/accuracy, to give slightly more weight to whichever of the 3 outputs
# has less accuracy
# Based on first edition of model ran on 10 epochs, with best checkpoint (on validation) retained
# I.e checkpoint 8 out of 10
acc_dict = val_results[-1]['training_accuracy']
acc_dict
# Out:
# {'Role': 0.8868475556373596,
#  'Function': 0.9789828658103943,
#  'Level': 0.9484805464744568}

# %%
# Calculate weights to use as inputs
weights_dict = {}
norm_factor = 0
for key in acc_dict:
    weights_dict[key]=1/acc_dict[key]
    norm_factor += weights_dict[key]
for key in weights_dict:
    weights_dict[key] = weights_dict[key]/norm_factor*3
weights_dict
# Out:
# {'Role': 1.0560011736018362,
#  'Function': 0.9566174161625742,
#  'Level': 0.9873814102355893}

# %%
# Can use above weights to run inference with loss option, and then come back here

# Bring in file from initial inference, as well as encoder for results

with open('../inference/15-02-2024_0007_inference.pkl','rb') as file:
    inference_results = pickle.load(file)

with open('../Data/index_label_mapping.pkl','rb') as file:
    encoder = pickle.load(file)

# %%
inference_results.head(20)
# Out:
#                                                 Title  Job Role  Job Function  \
# 0                                           Architect         3             1
# 1                             Ingeniero De Desarrollo         4             0
# 2                                         ???????????         4             2
# 3                      Sr. Offensive Security Manager         2             1
# 4                     Project Manager, Infrastructure         3             1
# 5               Co-Founder & Chief Technology Officer         1             1
# 6   System Administrator & Business Intelligence B...         5             1
# 7                                                 Cio         2             1
# 8                        Manager, Network Engineering         3             1
# 9         Services Supervisor, Information Technology         2             1
# 10     VP-Cybersecurity Architect, ISSAP, CCSP, CISSP         2             1
# 11                  Information Security Program Lead         2             1
# 12                                           Security         2             1
# 13                                          ?????????         5             1
# 14                             Head Of Cyber Security         2             1
# 15             Senior Manager, Information Technology         2             1
# 16                       Technology Platforms Manager         1             1
# 17                            Cyber Security Engineer         2             1
# 18  Adjoint Responsable De La Sécurité Des Système...         2             1
# 19                          Director, Global Programm         4             2
#
#     Job Level  Job Role Predicted  Job Function Predicted  \
# 0           1                   3                       1
# 1           1                   4                       0
# 2           1                   4                       2
# 3           4                   2                       1
# 4           4                   3                       1
# 5           3                   1                       1
# 6           1                   5                       1
# 7           0                   2                       1
# 8           4                   3                       1
# 9           4                   2                       1
# 10          3                   2                       1
# 11          4                   2                       1
# 12          1                   2                       1
# 13          4                   4                       2
# 14          3                   2                       1
# 15          4                   2                       1
# 16          4                   1                       1
# 17          1                   4                       1
# 18          4                   2                       1
# 19          2                   4                       2
#
#     Job Level Predicted      Loss
# 0                     1  0.001458
# 1                     1  0.005348
# 2                     1  1.630244
# 3                     4  0.019880
# 4                     4  0.004265
# 5                     3  0.001713
# 6                     1  0.022417
# 7                     0  0.596701
# 8                     4  0.000741
# 9                     4  0.065887
# 10                    3  0.000562
# 11                    4  0.043082
# 12                    1  0.068383
# 13                    1  3.650914
# 14                    3  0.000213
# 15                    4  0.332451
# 16                    4  0.043790
# 17                    1  1.397985
# 18                    4  0.006858
# 19                    2  0.002730

# %%
this_table_values = []
this_table_col_names = []
for column in inference_results:
    if column not in ['Title','Loss']:
        this_table_col_names.append(column+'_Text')
        this_col = column.replace(" Predicted","")
        this_col_vals = []
        for _,value in tqdm(enumerate(inference_results[column].tolist())):
            this_col_vals.append(encoder[this_col][value])
        this_table_values.append(this_col_vals)
add_df = pd.DataFrame({k:v for k,v in zip(this_table_col_names,this_table_values)})
inference_results = pd.concat([inference_results,add_df],axis = 1)
# Out:
# 1222412it [00:02, 469736.86it/s]
# 1222412it [00:02, 480992.78it/s]
# 1222412it [00:02, 473380.93it/s]
# 1222412it [00:02, 480666.08it/s]
# 1222412it [00:02, 475500.25it/s]
# 1222412it [00:02, 484029.21it/s]

# %%
# Now sort by loss descending to look at the observations that the model gets most wrong
inference_results_sorted = inference_results.sort_values(by='Loss',ascending=False)[['Title','Job Role_Text','Job Function_Text','Job Level_Text',
                                                                                    'Job Role Predicted_Text','Job Function Predicted_Text',
                                                                                    'Job Level Predicted_Text','Loss']]
inference_results_sorted.head(20)
# Out:
#                                        Title               Job Role_Text  \
# 272265    Chief Information Security Officer                  IT General
# 1002518                                  Cto                  Networking
# 254623                             DX???????                     Systems
# 166917           Security Operations Manager                  Networking
# 713354           Security Operations Manager                  Networking
# 476769                                  Issm        Information Security
# 251121                              Security  Governance Risk Compliance
# 574676                              Security  Governance Risk Compliance
# 955758                     Dirección General                     Non-ICP
# 290703                             Dirección                     Non-ICP
# 1042937                                  Isa        Information Security
# 869919         Head Of It Service Management  Governance Risk Compliance
# 449852               Senior Network Engineer                  IT General
# 972515   Head of Infrastructure and Platform                     Non-ICP
# 508846      Manager, Infrastructure Services                     Non-ICP
# 573214                           It Security                  IT General
# 385602      ???? ????????? ?3? ?????????3???                     Systems
# 1140421                                 Issm        Information Security
# 2859                                    Issm        Information Security
# 212070                                  CISO                  Networking
#
#         Job Function_Text Job Level_Text Job Role Predicted_Text  \
# 272265                 IT       Director    Information Security
# 1002518                IT        C-Level              IT General
# 254623                 IT    Contributor                 Non-ICP
# 166917            Non-ICP        Manager    Information Security
# 713354            Non-ICP        Manager    Information Security
# 476769        Engineering    Contributor                 Non-ICP
# 251121                 IT        Manager    Information Security
# 574676                 IT        Manager    Information Security
# 955758            Non-ICP       Director    Information Security
# 290703            Non-ICP       Director    Information Security
# 1042937                IT    Contributor                 Non-ICP
# 869919                 IT      Executive    Information Security
# 449852                 IT    Contributor              Networking
# 972515                 IT      Executive              Networking
# 508846                 IT        Manager              Networking
# 573214                 IT       Director    Information Security
# 385602        Engineering        C-Level                 Non-ICP
# 1140421                IT        C-Level                 Non-ICP
# 2859                   IT        C-Level                 Non-ICP
# 212070                 IT        C-Level    Information Security
#
#         Job Function Predicted_Text Job Level Predicted_Text       Loss
# 272265                           IT                  C-Level  21.508377
# 1002518                          IT                Executive  20.611830
# 254623                      Non-ICP                  Manager  15.255075
# 166917                           IT                  Manager  15.049135
# 713354                           IT                  Manager  15.049135
# 476769                      Non-ICP                  Manager  14.638029
# 251121                           IT              Contributor  13.821310
# 574676                           IT              Contributor  13.821310
# 955758                           IT                  C-Level  13.527388
# 290703                           IT                  C-Level  13.114651
# 1042937                     Non-ICP              Contributor  13.025041
# 869919                           IT                Executive  12.945917
# 449852                           IT              Contributor  12.458189
# 972515                           IT                Executive  12.384545
# 508846                           IT                  Manager  12.314246
# 573214                           IT              Contributor  12.177299
# 385602                      Non-ICP              Contributor  12.152667
# 1140421                     Non-ICP                  Manager  12.138388
# 2859                        Non-ICP                  Manager  12.138388
# 212070                           IT                  C-Level  12.131436
