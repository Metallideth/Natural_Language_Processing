# %%
import pickle
import pandas as pd
from tqdm import tqdm
import dataframe_image as dfi

# %%
# Load in validation results
with open('../logging/26-02-2024_1922/epoch08_train_val_summary','rb') as file:
    val_results = pickle.load(file)

# %%
# Take a look at accuracy of the validation results - these will be used to establish the weights for the loss function
# As in the model training, the weights for loss are based on 1/accuracy, to give slightly more weight to whichever of the 3 outputs
# has less accuracy
# Based on first edition of model ran on 20 epochs, with best checkpoint (on validation) retained
# I.e checkpoint 9 out of 10
acc_dict = val_results[-1]['training_accuracy']
acc_dict
# Out:
# {'Role': 0.976859986782074,
#  'Function': 0.9978083968162537,
#  'Level': 0.9902929663658142}

# %%
# Calculate weights to use as inputs
weights_dict = {}
norm_factor = 0
for key in acc_dict:
    weights_dict[key]=1/acc_dict[key]
    norm_factor += weights_dict[key]
for key in weights_dict:
    weights_dict[key] = weights_dict[key]/norm_factor*3
weights_dict
# Out:
# {'Role': 1.0116539409992857,
#  'Function': 0.990414851774975,
#  'Level': 0.9979312072257394}

# %%
# Can use above weights to run inference with loss option, and then come back here

# Bring in file from initial inference, as well as encoder for results

with open('../inference/27-02-2024_1239_inference.pkl','rb') as file:
    inference_results = pickle.load(file)

with open('../Data/index_label_mapping.pkl','rb') as file:
    encoder = pickle.load(file)

# %%
inference_results.head(20)
# Out:
#                                                 Title  Job Function  Job Role  \
# 0                                         IT DIRECTOR             1         4
# 1                            ENGLISH DEPARTMENT CHAIR             2         5
# 2   SENIOR DIRECTOR, HOME FRAGRANCE INFORMATION TE...             1         4
# 3                     MANAGER, INFORMATION TECHNOLOGY             1         2
# 4                   2X CERTIFIED SALESFORCE DEVELOPER             2         5
# 5                       NETWORK OPERATIONS SPECIALIST             1         4
# 6                  DIRECTOR CYBER POLICY AND PLANNING             1         4
# 7                         MANAGER, NETWORK OPERATIONS             1         4
# 8        REGIONAL MANAGER, NETWORK OPERATIONS SUPPORT             1         4
# 9                                       IT SPECIALIST             1         2
# 10                                 IT SR TECH ANALYST             1         2
# 11                                         IT ANALYST             1         2
# 12                   DIRECTOR, INFORMATION TECHNOLOGY             1         4
# 13                                PRINCIPAL ARCHITECT             1         4
# 14              MANAGER,IDENTITY AND ACCESS MANGEMENT             1         2
# 15           VICE PRESIDENT, SYSTEMS INNOVATION GROUP             1         0
# 16                       DIRECTOR, EXECUTIVE PROGRAMS             2         4
# 17                   INFORMATION TECHNOLOGY EXECUTIVE             1         2
# 18                       VP/CFO, FINANCIAL OPERATIONS             2         5
# 19                       SYSTEMS ACQUISITIONS MANAGER             1         2
#
#     Job Level  Job Role Predicted  Job Function Predicted  \
# 0           2                   4                       1
# 1           2                   5                       2
# 2           2                   4                       1
# 3           4                   2                       1
# 4           1                   5                       2
# 5           1                   4                       1
# 6           2                   4                       1
# 7           4                   4                       1
# 8           4                   5                       1
# 9           1                   2                       1
# 10          1                   2                       1
# 11          1                   2                       1
# 12          2                   4                       1
# 13          4                   4                       1
# 14          4                   2                       1
# 15          3                   0                       1
# 16          2                   4                       2
# 17          3                   2                       1
# 18          0                   5                       2
# 19          4                   2                       1
#
#     Job Level Predicted      Loss
# 0                     2  0.000014
# 1                     2  0.002494
# 2                     2  0.153269
# 3                     4  0.000006
# 4                     1  0.080020
# 5                     1  0.000016
# 6                     2  0.410957
# 7                     4  0.000009
# 8                     4  2.414484
# 9                     1  0.000020
# 10                    1  0.014778
# 11                    1  0.000015
# 12                    2  0.000018
# 13                    4  0.000027
# 14                    4  0.000216
# 15                    3  0.022707
# 16                    2  0.017610
# 17                    3  0.000024
# 18                    0  0.032702
# 19                    4  0.172714

# %%
this_table_values = []
this_table_col_names = []
for column in inference_results:
    if column not in ['Title','Loss']:
        this_table_col_names.append(column+'_Text')
        this_col = column.replace(" Predicted","")
        this_col_vals = []
        for _,value in tqdm(enumerate(inference_results[column].tolist())):
            this_col_vals.append(encoder[this_col][value])
        this_table_values.append(this_col_vals)
add_df = pd.DataFrame({k:v for k,v in zip(this_table_col_names,this_table_values)})
inference_results = pd.concat([inference_results,add_df],axis = 1)
# Out:
# 0it [00:00, ?it/s]
# 669785it [00:00, 2962883.72it/s]
# 669785it [00:00, 3259697.07it/s]
# 669785it [00:00, 3379595.39it/s]
# 669785it [00:00, 3138283.90it/s]
# 669785it [00:00, 3162697.54it/s]
# 669785it [00:00, 3268742.95it/s]

# %%
# Now sort by loss descending to look at the observations that the model gets most wrong
inference_results_sorted = inference_results.sort_values(by='Loss',ascending=False)[['Title','Job Role_Text','Job Function_Text','Job Level_Text',
                                                                                    'Job Role Predicted_Text','Job Function Predicted_Text',
                                                                                    'Job Level Predicted_Text','Loss']]
inference_results_sorted.head(20)
# Out:
#                                                     Title  \
# 377261                                                ÈNG
# 281934                                              SR.PM
# 651377                                              SR.PM
# 584419                         NETWORK  SECURITY ENGINEER
# 310351            IT VICE PRESIDENT, INFORMATION SECURITY
# 127468  SENIOR MANAGER, INFORMATION TECHNOLOGY INFRAST...
# 231917          ASSISTANT VP, NETWORK SECURITY OPERATIONS
# 176880                  MANAGER, COMPUTING INFRASTRUCTURE
# 21019                                           CTO / CSO
# 489206                      DIRECTOR, TECHNOLOGY SECURITY
# 349551                        ACCOUNT MANAGER, OPERATIONS
# 282273   DIRECTOR, INFORMATION SECURITY & COMPLIANCE, GRC
# 527554                              SR.COMPLIANCE OFFICER
# 451748  VICE PRESIDENT, CYBER SECURITY & SENIOR RISK E...
# 27672          SR. SOLUTIONS CONSULTANT VEC BUSINESS UNIT
# 203315                 SENIOR MANAGER, QUALITY MANAGEMENT
# 148406                IT SYSTEMS & SECURITY ADMINISTRATOR
# 147972                  SENIOR MANAGER, SECURITY SERVICES
# 289153       DATA SCIENCE MANAGER, INFORMATION TECHNOLOGY
# 82869               SENIOR DIRECTOR, CORPORATE TECHNOLOGY
#
#                      Job Role_Text Job Function_Text Job Level_Text  \
# 377261                     NON-ICP           NON-ICP    CONTRIBUTOR
# 281934                     NON-ICP           NON-ICP    CONTRIBUTOR
# 651377                     NON-ICP           NON-ICP    CONTRIBUTOR
# 584419        INFORMATION SECURITY                IT    CONTRIBUTOR
# 310351        INFORMATION SECURITY                IT        C-LEVEL
# 127468        INFORMATION SECURITY                IT        UNKNOWN
# 231917        INFORMATION SECURITY                IT      EXECUTIVE
# 176880                     NON-ICP                IT        MANAGER
# 21019                      SYSTEMS                IT      EXECUTIVE
# 489206        INFORMATION SECURITY                IT       DIRECTOR
# 349551                  NETWORKING           NON-ICP    CONTRIBUTOR
# 282273                  NETWORKING                IT       DIRECTOR
# 527554  GOVERNANCE RISK COMPLIANCE                IT      EXECUTIVE
# 451748                  IT GENERAL                IT      EXECUTIVE
# 27672                      NON-ICP           NON-ICP    CONTRIBUTOR
# 203315                 DEVELOPMENT           NON-ICP        MANAGER
# 148406        INFORMATION SECURITY                IT       DIRECTOR
# 147972        INFORMATION SECURITY                IT        UNKNOWN
# 289153                  IT GENERAL                IT        MANAGER
# 82869         INFORMATION SECURITY                IT       DIRECTOR
#
#            Job Role Predicted_Text Job Function Predicted_Text  \
# 377261                 DEVELOPMENT                 ENGINEERING
# 281934                 DEVELOPMENT                 ENGINEERING
# 651377                 DEVELOPMENT                 ENGINEERING
# 584419                  NETWORKING                          IT
# 310351        INFORMATION SECURITY                          IT
# 127468        INFORMATION SECURITY                          IT
# 231917                  NETWORKING                          IT
# 176880                  NETWORKING                          IT
# 21019                   NETWORKING                          IT
# 489206                  NETWORKING                          IT
# 349551                     NON-ICP                     NON-ICP
# 282273  GOVERNANCE RISK COMPLIANCE                          IT
# 527554  GOVERNANCE RISK COMPLIANCE                          IT
# 451748        INFORMATION SECURITY                          IT
# 27672                   NETWORKING                          IT
# 203315                     NON-ICP                     NON-ICP
# 148406        INFORMATION SECURITY                          IT
# 147972        INFORMATION SECURITY                          IT
# 289153                     NON-ICP                          IT
# 82869                   NETWORKING                          IT
#
#        Job Level Predicted_Text       Loss
# 377261              CONTRIBUTOR  17.035435
# 281934                  MANAGER  14.895061
# 651377                  MANAGER  14.895061
# 584419              CONTRIBUTOR  12.008307
# 310351                EXECUTIVE  11.363048
# 127468                  MANAGER  10.772053
# 231917              CONTRIBUTOR  10.501913
# 176880                  MANAGER  10.376395
# 21019                   C-LEVEL  10.323332
# 489206                 DIRECTOR  10.300467
# 349551              CONTRIBUTOR  10.280710
# 282273                 DIRECTOR  10.186845
# 527554                  C-LEVEL  10.081469
# 451748                EXECUTIVE  10.063582
# 27672               CONTRIBUTOR   9.883533
# 203315                  MANAGER   9.842991
# 148406              CONTRIBUTOR   9.741222
# 147972                  MANAGER   9.695919
# 289153                  MANAGER   9.692524
# 82869                  DIRECTOR   9.690509

# %% [markdown]
# Overall I think I'm fine with the differences above, yes the model does appear to be inaccurate in certain circumstances but considering these are where the model diverges the most with the actual historical tagged I'm fine if there are some errors, since the model can't be perfect. Indeed, most of the above also have a reasonable explanation for the model picks as well.

# %%
top_inaccuracies = inference_results_sorted.head(20)
top_inaccuracies.columns = [['','Actual','Actual','Actual','Predicted','Predicted','Predicted',''],['Title','Role','Function','Level','Role','Function','Level','Loss']]
dfi.export(top_inaccuracies,'../Reports/Top_Loss.png')

# %%
inference_results.loc[(inference_results['Job Role Predicted_Text'] == 'GOVERNANCE RISK COMPLIANCE') & (inference_results['Job Function Predicted_Text'] != 'RISK/LEGAL/COMPLIANCE')][['Title','Job Role_Text','Job Function_Text','Job Level_Text',
                                                                                    'Job Role Predicted_Text','Job Function Predicted_Text',
                                                                                    'Job Level Predicted_Text','Loss']]
# Out:
#                                                     Title  \
# 85                                       VP OF COMPLIANCE
# 89                          DIRECTOR, RISK QUANTIFICATION
# 114           DATA GOVERNANCE SPECIALIST & VICE PRESIDENT
# 178                         MANAGER, AUDIT AND COMPLIANCE
# 318                     CYBER SECURITY COMPLIANCE ANALYST
# ...                                                   ...
# 669438              DIRECTOR, SECURITY, RISK & COMPLIANCE
# 669478                                  SR. AUDIT MANAGER
# 669546                         MANAGER CUSTOMS COMPLIANCE
# 669739  COMPLIANCE/RISK/PRIVACY DIRECTOR/MANAGER/CONSU...
# 669767  DIRECTOR, INFORMATION SECURITY RISK AND COMPLI...
#
#                      Job Role_Text Job Function_Text Job Level_Text  \
# 85      GOVERNANCE RISK COMPLIANCE                IT      EXECUTIVE
# 89      GOVERNANCE RISK COMPLIANCE                IT       DIRECTOR
# 114     GOVERNANCE RISK COMPLIANCE                IT      EXECUTIVE
# 178     GOVERNANCE RISK COMPLIANCE                IT        MANAGER
# 318     GOVERNANCE RISK COMPLIANCE                IT    CONTRIBUTOR
# ...                            ...               ...            ...
# 669438  GOVERNANCE RISK COMPLIANCE                IT       DIRECTOR
# 669478  GOVERNANCE RISK COMPLIANCE                IT        MANAGER
# 669546  GOVERNANCE RISK COMPLIANCE                IT        MANAGER
# 669739  GOVERNANCE RISK COMPLIANCE                IT    CONTRIBUTOR
# 669767  GOVERNANCE RISK COMPLIANCE                IT       DIRECTOR
#
#            Job Role Predicted_Text Job Function Predicted_Text  \
# 85      GOVERNANCE RISK COMPLIANCE                          IT
# 89      GOVERNANCE RISK COMPLIANCE                          IT
# 114     GOVERNANCE RISK COMPLIANCE                          IT
# 178     GOVERNANCE RISK COMPLIANCE                          IT
# 318     GOVERNANCE RISK COMPLIANCE                          IT
# ...                            ...                         ...
# 669438  GOVERNANCE RISK COMPLIANCE                          IT
# 669478  GOVERNANCE RISK COMPLIANCE                          IT
# 669546  GOVERNANCE RISK COMPLIANCE                          IT
# 669739  GOVERNANCE RISK COMPLIANCE                          IT
# 669767  GOVERNANCE RISK COMPLIANCE                          IT
#
#        Job Level Predicted_Text      Loss
# 85                    EXECUTIVE  0.010169
# 89                     DIRECTOR  0.053843
# 114                   EXECUTIVE  0.352693
# 178                     MANAGER  0.002494
# 318                 CONTRIBUTOR  0.182990
# ...                         ...       ...
# 669438                 DIRECTOR  0.172749
# 669478                  MANAGER  0.000554
# 669546                  MANAGER  0.013966
# 669739              CONTRIBUTOR  0.000914
# 669767                 DIRECTOR  0.094542
#
# [16494 rows x 8 columns]

# %% [markdown]
# Based on eyeballing a few of the above, the desired Function mapping of Risk/Legal/Compliance should probably also include the Role of Governance Risk Compliance, i.e. whatever function is in there should be overwritten to be Risk/Legal/Compliance when the Role is Risk/Legal/Compliance.

# %%
inference_results.loc[(inference_results['Job Function Predicted_Text'] == 'IT') & (inference_results['Job Role Predicted_Text'] == 'NON-ICP')][['Title','Job Role_Text','Job Function_Text','Job Level_Text',
                                                                                    'Job Role Predicted_Text','Job Function Predicted_Text',
                                                                                    'Job Level Predicted_Text','Loss']]
# Out:
#                                                   Title Job Role_Text  \
# 8          REGIONAL MANAGER, NETWORK OPERATIONS SUPPORT    NETWORKING
# 79                       MANAGER, DATA CENTER FACILTIES       NON-ICP
# 81                               SENIOR PROJECT MANAGER       NON-ICP
# 111                                     PROJECT MANAGER       NON-ICP
# 130              TEAM LEAD, COMPUTER SUPPORT TECHNICIAN       NON-ICP
# ...                                                 ...           ...
# 669651                                     DATA ANALYST       NON-ICP
# 669654                         PROJECT MANAGER, SYSTEMS       NON-ICP
# 669710                MANAGER, CONFIGURATION MANAGEMENT       NON-ICP
# 669722      CUSTOMER SERVICE DIRECTOR, NETWORK SERVICES       NON-ICP
# 669728  MANAGER, SYSTEMS INTEGRATION AND DATABASE GROUP    IT GENERAL
#
#        Job Function_Text Job Level_Text Job Role Predicted_Text  \
# 8                     IT        MANAGER                 NON-ICP
# 79                    IT        MANAGER                 NON-ICP
# 81                    IT        MANAGER                 NON-ICP
# 111                   IT        MANAGER                 NON-ICP
# 130                   IT    CONTRIBUTOR                 NON-ICP
# ...                  ...            ...                     ...
# 669651                IT    CONTRIBUTOR                 NON-ICP
# 669654                IT        MANAGER                 NON-ICP
# 669710                IT        MANAGER                 NON-ICP
# 669722                IT       DIRECTOR                 NON-ICP
# 669728                IT        MANAGER                 NON-ICP
#
#        Job Function Predicted_Text Job Level Predicted_Text      Loss
# 8                               IT                  MANAGER  2.414484
# 79                              IT                  MANAGER  0.000041
# 81                              IT                  MANAGER  0.000066
# 111                             IT                  MANAGER  0.000010
# 130                             IT              CONTRIBUTOR  0.074014
# ...                            ...                      ...       ...
# 669651                          IT              CONTRIBUTOR  0.000045
# 669654                          IT                  MANAGER  0.000246
# 669710                          IT                  MANAGER  0.002323
# 669722                          IT                 DIRECTOR  0.023922
# 669728                          IT                  MANAGER  2.027697
#
# [21655 rows x 8 columns]

# %%
# Take any and all results that don't agree between the predicted and actual and write to excel
writer = pd.ExcelWriter('../inference/model_historic_divergence.xlsx',engine = 'xlsxwriter')
inference_results_sorted.loc[(inference_results_sorted['Job Role_Text'] != inference_results_sorted['Job Role Predicted_Text']) | (inference_results_sorted['Job Function_Text'] != inference_results_sorted['Job Function Predicted_Text']) | (inference_results_sorted['Job Level_Text'] != inference_results_sorted['Job Level Predicted_Text'])
                             ].groupby(['Title','Job Role_Text','Job Function_Text','Job Level_Text','Job Role Predicted_Text',
                                        'Job Function Predicted_Text','Job Level Predicted_Text','Loss']).size().reset_index(name='Counts').sort_values(by='Loss',ascending=False).to_excel(
    writer, sheet_name = 'Prediction_Divergences',index = False
)
writer.close()
