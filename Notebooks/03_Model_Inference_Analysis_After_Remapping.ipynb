# %%
import os
import pickle
import pandas as pd
import numpy as np
from operator import itemgetter
from tqdm import tqdm

# %%
# Load in validation results
with open('../logging/21-02-2024_0846/epoch00_train_val_summary','rb') as file:
    val_results = pickle.load(file)

# %%
# Take a look at accuracy of the validation results - these will be used to establish the weights for the loss function
# As in the model training, the weights for loss are based on 1/accuracy, to give slightly more weight to whichever of the 3 outputs
# has less accuracy
# Based on first edition of model ran on 10 epochs, with best checkpoint (on validation) retained
# I.e checkpoint 8 out of 10
acc_dict = val_results[-1]['training_accuracy']
acc_dict
# Out:
# {'Role': 0.9826903343200684,
#  'Function': 0.9983294010162354,
#  'Level': 0.9928633570671082}

# %%
# Calculate weights to use as inputs
weights_dict = {}
norm_factor = 0
for key in acc_dict:
    weights_dict[key]=1/acc_dict[key]
    norm_factor += weights_dict[key]
for key in weights_dict:
    weights_dict[key] = weights_dict[key]/norm_factor*3
weights_dict
# Out:
# {'Role': 1.0087123775354698,
#  'Function': 0.9929106590511017,
#  'Level': 0.9983769634134283}

# %%
# Can use above weights to run inference with loss option, and then come back here

# Bring in file from initial inference, as well as encoder for results

with open('../inference/21-02-2024_1718_inference.pkl','rb') as file:
    inference_results = pickle.load(file)

with open('../Data/index_label_mapping.pkl','rb') as file:
    encoder = pickle.load(file)

# %%
inference_results.head(20)
# Out:
#                                                 Title  Job Function  Job Role  \
# 0                                         IT DIRECTOR             1         3
# 1                            ENGLISH DEPARTMENT CHAIR             2         4
# 2   SENIOR DIRECTOR, HOME FRAGRANCE INFORMATION TE...             1         3
# 3                     MANAGER, INFORMATION TECHNOLOGY             1         1
# 4                   2X CERTIFIED SALESFORCE DEVELOPER             2         4
# 5                       NETWORK OPERATIONS SPECIALIST             1         3
# 6                  DIRECTOR CYBER POLICY AND PLANNING             1         3
# 7                         MANAGER, NETWORK OPERATIONS             1         3
# 8        REGIONAL MANAGER, NETWORK OPERATIONS SUPPORT             1         3
# 9                                       IT SPECIALIST             1         1
# 10                                 IT SR TECH ANALYST             1         1
# 11                                         IT ANALYST             1         1
# 12                   DIRECTOR, INFORMATION TECHNOLOGY             1         3
# 13                                PRINCIPAL ARCHITECT             1         3
# 14              MANAGER,IDENTITY AND ACCESS MANGEMENT             1         1
# 15           VICE PRESIDENT, SYSTEMS INNOVATION GROUP             1         4
# 16                       DIRECTOR, EXECUTIVE PROGRAMS             2         3
# 17                   INFORMATION TECHNOLOGY EXECUTIVE             1         1
# 18                       VP/CFO, FINANCIAL OPERATIONS             2         4
# 19                       SYSTEMS ACQUISITIONS MANAGER             1         1
#
#     Job Level  Job Role Predicted  Job Function Predicted  \
# 0           2                   3                       1
# 1           2                   4                       2
# 2           2                   3                       1
# 3           4                   1                       1
# 4           1                   4                       2
# 5           1                   3                       1
# 6           2                   3                       1
# 7           4                   3                       1
# 8           4                   4                       1
# 9           1                   1                       1
# 10          1                   1                       1
# 11          1                   1                       1
# 12          2                   3                       1
# 13          4                   3                       1
# 14          4                   1                       1
# 15          3                   4                       1
# 16          2                   3                       2
# 17          3                   1                       1
# 18          0                   4                       2
# 19          4                   1                       1
#
#     Job Level Predicted      Loss
# 0                     2  0.000005
# 1                     2  0.000867
# 2                     2  0.003066
# 3                     4  0.000008
# 4                     1  0.018354
# 5                     1  0.000007
# 6                     2  0.020832
# 7                     4  0.000008
# 8                     4  0.820420
# 9                     1  0.000009
# 10                    1  0.099906
# 11                    1  0.000019
# 12                    2  0.000003
# 13                    4  0.000016
# 14                    4  0.000126
# 15                    3  0.000790
# 16                    2  0.014252
# 17                    3  0.000067
# 18                    0  0.018194
# 19                    4  0.006555

# %%
this_table_values = []
this_table_col_names = []
for column in inference_results:
    if column not in ['Title','Loss']:
        this_table_col_names.append(column+'_Text')
        this_col = column.replace(" Predicted","")
        this_col_vals = []
        for _,value in tqdm(enumerate(inference_results[column].tolist())):
            this_col_vals.append(encoder[this_col][value])
        this_table_values.append(this_col_vals)
add_df = pd.DataFrame({k:v for k,v in zip(this_table_col_names,this_table_values)})
inference_results = pd.concat([inference_results,add_df],axis = 1)
# Out:
# 669785it [00:00, 2972920.36it/s]
# 669785it [00:00, 3401561.85it/s]
# 669785it [00:00, 3452198.67it/s]
# 669785it [00:00, 3421001.43it/s]
# 669785it [00:00, 3373066.33it/s]
# 669785it [00:00, 3277693.86it/s]

# %%
# Now sort by loss descending to look at the observations that the model gets most wrong
inference_results_sorted = inference_results.sort_values(by='Loss',ascending=False)[['Title','Job Role_Text','Job Function_Text','Job Level_Text',
                                                                                    'Job Role Predicted_Text','Job Function Predicted_Text',
                                                                                    'Job Level Predicted_Text','Loss']]
inference_results_sorted.head(20)
# Out:
#                                                     Title  \
# 584419                         NETWORK  SECURITY ENGINEER
# 377261                                                ÈNG
# 176880                  MANAGER, COMPUTING INFRASTRUCTURE
# 58109                          MANAGER, SYSTEMS & SUPPORT
# 638590  EXECUTIVE DIRECTOR, HEAD OF SOLUTION ARCHITECT...
# 424083            DIRECTOR, END-USER COMPUTING OPERATIONS
# 53254                            CHIEF FINANCIAL  OFFICER
# 133170                           CHIEF FINANCIAL  OFFICER
# 328736              PRINCIPAL CYBERSECURITY ADMINISTRATOR
# 622010                               NETWORK SPECIALIST 2
# 282273   DIRECTOR, INFORMATION SECURITY & COMPLIANCE, GRC
# 519769                                           SVP  CTO
# 509883            ENTERPRISE NETWORK & SECURITY ARCHITECT
# 553603          VICE PRESIDENT/ CHIEF INFORMATION OFFICER
# 207058          VICE PRESIDENT/ CHIEF INFORMATION OFFICER
# 218427               SUPERVISOR OF INFORMATION TECHNOLOGY
# 232677                      DIRECTOR , SERVICE MANAGEMENT
# 367518   VICE PRESIDENT & CHIEF INFORMATION OFFICER (CIO)
# 439249                                    IT-PROJEKTLEDER
# 399816  EXECUTIVE ASSISTANT TO INTERNATIONAL CHIEF INF...
#
#                Job Role_Text Job Function_Text Job Level_Text  \
# 584419  INFORMATION SECURITY                IT    CONTRIBUTOR
# 377261               NON-ICP           NON-ICP    CONTRIBUTOR
# 176880               NON-ICP                IT        MANAGER
# 58109   INFORMATION SECURITY                IT        MANAGER
# 638590            IT GENERAL                IT      EXECUTIVE
# 424083               NON-ICP                IT       DIRECTOR
# 53254                SYSTEMS           NON-ICP        C-LEVEL
# 133170               SYSTEMS           NON-ICP        C-LEVEL
# 328736               SYSTEMS                IT    CONTRIBUTOR
# 622010            NETWORKING                IT        UNKNOWN
# 282273            NETWORKING                IT       DIRECTOR
# 519769            IT GENERAL                IT        UNKNOWN
# 509883  INFORMATION SECURITY                IT    CONTRIBUTOR
# 553603            IT GENERAL                IT        C-LEVEL
# 207058            IT GENERAL                IT        C-LEVEL
# 218427            IT GENERAL                IT        MANAGER
# 232677            NETWORKING           NON-ICP       DIRECTOR
# 367518            IT GENERAL                IT        C-LEVEL
# 439249            IT GENERAL                IT        UNKNOWN
# 399816  INFORMATION SECURITY           NON-ICP    CONTRIBUTOR
#
#            Job Role Predicted_Text Job Function Predicted_Text  \
# 584419                  NETWORKING                          IT
# 377261                     NON-ICP                 ENGINEERING
# 176880                  NETWORKING                          IT
# 58109                      NON-ICP                          IT
# 638590                  NETWORKING                          IT
# 424083                  NETWORKING                          IT
# 53254                      NON-ICP                     NON-ICP
# 133170                     NON-ICP                     NON-ICP
# 328736        INFORMATION SECURITY                          IT
# 622010                  NETWORKING                          IT
# 282273  GOVERNANCE RISK COMPLIANCE                          IT
# 519769                  IT GENERAL                          IT
# 509883                  NETWORKING                          IT
# 553603        INFORMATION SECURITY                          IT
# 207058        INFORMATION SECURITY                          IT
# 218427        INFORMATION SECURITY                          IT
# 232677                     NON-ICP                     NON-ICP
# 367518        INFORMATION SECURITY                          IT
# 439249                     NON-ICP                     NON-ICP
# 399816                     NON-ICP                     NON-ICP
#
#        Job Level Predicted_Text       Loss
# 584419              CONTRIBUTOR  13.767385
# 377261              CONTRIBUTOR  11.715264
# 176880                  MANAGER  11.547041
# 58109                   MANAGER  11.068710
# 638590                EXECUTIVE  10.532409
# 424083                 DIRECTOR  10.000492
# 53254                   C-LEVEL   9.964821
# 133170                  C-LEVEL   9.964821
# 328736                  MANAGER   9.948408
# 622010              CONTRIBUTOR   9.923821
# 282273                 DIRECTOR   9.878128
# 519769                EXECUTIVE   9.367645
# 509883              CONTRIBUTOR   9.249187
# 553603                EXECUTIVE   9.131094
# 207058                EXECUTIVE   9.131094
# 218427                  MANAGER   9.058119
# 232677                 DIRECTOR   8.882878
# 367518                EXECUTIVE   8.775103
# 439249                  UNKNOWN   8.633453
# 399816                EXECUTIVE   8.627908
